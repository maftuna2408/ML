# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
df = pd.read_csv('Social Media and Mental health.csv')
df.head()
# Out:
#             Timestamp  1. What is your age? 2. Gender 3. Relationship Status  \
# 0  4/18/2022 19:18:47                  21.0      Male      In a relationship
# 1  4/18/2022 19:19:28                  21.0    Female                 Single
# 2  4/18/2022 19:25:59                  21.0    Female                 Single
# 3  4/18/2022 19:29:43                  21.0    Female                 Single
# 4  4/18/2022 19:33:31                  21.0    Female                 Single
#
#   4. Occupation Status 5. What type of organizations are you affiliated with?  \
# 0   University Student                                         University
# 1   University Student                                         University
# 2   University Student                                         University
# 3   University Student                                         University
# 4   University Student                                         University
#
#   6. Do you use social media?  \
# ...

# %%
df.tail(10)
# Out:
#                Timestamp  1. What is your age? 2. Gender  \
# 471   5/16/2022 20:20:31                  20.0    Female
# 472   5/17/2022 17:12:19                  35.0    Female
# 473    5/18/2022 2:12:59                  26.0    Female
# 474   5/21/2022 22:19:10                  30.0    Female
# 475   5/21/2022 22:33:02                  32.0    Female
# 476   5/21/2022 23:38:28                  24.0      Male
# 477    5/22/2022 0:01:05                  26.0    Female
# 478   5/22/2022 10:29:21                  29.0    Female
# 479   7/14/2022 19:33:47                  21.0      Male
# 480  11/12/2022 13:16:50                  53.0      Male
#
#     3. Relationship Status 4. Occupation Status  \
# 471                 Single   University Student
# 472                Married      Salaried Worker
# 473                Married   University Student
# 474                Married      Salaried Worker
# 475                Married      Salaried Worker
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 481 entries, 0 to 480
# Data columns (total 21 columns):
#  #   Column                                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                                --------------  -----
#  0   Timestamp                                                                                                             481 non-null    object
#  1   1. What is your age?                                                                                                  481 non-null    float64
#  2   2. Gender                                                                                                             481 non-null    object
#  3   3. Relationship Status                                                                                                481 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# Timestamp                                                                                                                0
# 1. What is your age?                                                                                                     0
# 2. Gender                                                                                                                0
# 3. Relationship Status                                                                                                   0
# 4. Occupation Status                                                                                                     0
# 5. What type of organizations are you affiliated with?                                                                  30
# 6. Do you use social media?                                                                                              0
# 7. What social media platforms do you commonly use?                                                                      0
# ...

# %%
mode_value = df['5. What type of organizations are you affiliated with?'].mode()
print(mode_value)
# Out:
# 0    University
# Name: 5. What type of organizations are you affiliated with?, dtype: object

# %%
df.fillna(df['5. What type of organizations are you affiliated with?'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# Timestamp                                                                                                               0
# 1. What is your age?                                                                                                    0
# 2. Gender                                                                                                               0
# 3. Relationship Status                                                                                                  0
# 4. Occupation Status                                                                                                    0
# 5. What type of organizations are you affiliated with?                                                                  0
# 6. Do you use social media?                                                                                             0
# 7. What social media platforms do you commonly use?                                                                     0
# ...

# %%
df.columns = [col.split('. ', 1)[-1] for col in df.columns]
df.columns
# Out:
# Index(['Timestamp', 'What is your age?', 'Gender', 'Relationship Status',
#        'Occupation Status',
#        'What type of organizations are you affiliated with?',
#        'Do you use social media?',
#        'What social media platforms do you commonly use?',
#        'What is the average time you spend on social media every day?',
#        'How often do you find yourself using Social media without a specific purpose?',
#        'How often do you get distracted by Social media when you are busy doing something?',
#        'Do you feel restless if you haven't used Social media in a while?',
#        'On a scale of 1 to 5, how easily distracted are you?',
#        'On a scale of 1 to 5, how much are you bothered by worries?',
#        'Do you find it difficult to concentrate on things?',
#        'On a scale of 1-5, how often do you compare yourself to other successful people through the use of social media?',
# ...

# %%
print(df['Gender'].unique())
# Out:
# ['Male' 'Female' 'Nonbinary ' 'Non-binary' 'NB' 'unsure ' 'Trans'
#  'Non binary ' 'There are others???']

# %%
# o'zgaruvci yaratib, label encoderni chaqirib olish
label_encoder = LabelEncoder() 
df['Gender'] = label_encoder.fit_transform(df['Gender'])
df['What is the average time you spend on social media every day?'] = label_encoder.fit_transform(df['What is the average time you spend on social media every day?'])

# %%
df['Gender']
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 476    1
# 477    0
# 478    0
# 479    1
# 480    1
# Name: Gender, Length: 481, dtype: int64

# %%
print(df['Gender'].unique())
# Out:
# [1 0 5 4 2 8 7 3 6]

# %%
onehotencoder = OneHotEncoder()
df['']
