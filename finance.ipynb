# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Maftuna\AppData\Local\Temp\3b2a1ca2-b593-4f3b-8b23-452faafd24a0_dataset.csv.zip.4a0\dataset.csv', index_col=0 )
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv(r'C:\Users\Maftuna\AppData\Local\Temp\3b2a1ca2-b593-4f3b-8b23-452faafd24a0_dataset.csv.zip.4a0\dataset.csv', index_col=0 )
#       2 df.head(10)
#
# ...

# %%
df.tail(10)
# Out:
#             open       high        low      close        volume     marketCap  \
# 72936   4.905588   5.029796   4.813594   5.021913  2.784509e+07  1.350319e+09
# 72937   8.848058   9.121299   8.324531   8.726945  5.018698e+07  1.338344e+09
# 72938   0.059729   0.060795   0.058552   0.060573  2.172372e+07  1.391261e+09
# 72939  22.580207  23.184871  22.421821  23.147571  3.469170e+07  3.084676e+09
# 72940   1.383998   1.406040   1.354278   1.404507  4.750240e+06  1.715466e+09
# 72941   0.022604   0.022988   0.022197   0.022796  4.040134e+07  1.652957e+09
# 72942   1.468244   1.530464   1.435415   1.517878  2.844351e+07  1.572825e+09
# 72943   4.950431   5.148565   4.945280   5.117206  1.069497e+08  1.559551e+09
# 72944   0.000233   0.000243   0.000226   0.000239  2.143268e+08  1.576291e+09
# 72945   0.465490   0.471006   0.453438   0.469033  9.509743e+08  2.339868e+10
#
#                       timestamp        crypto_name        date
# ...

# %%
df.describe()
# Out:
#                open          high           low         close        volume  \
# count  72946.000000  7.294600e+04  72946.000000  7.294600e+04  7.294600e+04
# mean     870.194495  8.964124e+02    844.060640  8.712949e+02  2.207607e+09
# std     5231.654470  5.398613e+03   5079.389387  5.235508e+03  9.617885e+09
# min        0.000000  1.022100e-10      0.000000  8.292000e-11  0.000000e+00
# 25%        0.167916  1.767999e-01      0.158630  1.682982e-01  8.320618e+06
# 50%        1.630666  1.717542e+00      1.541486  1.640219e+00  1.098756e+08
# 75%       26.070557  2.756868e+01     24.791776  2.625195e+01  6.691398e+08
# max    67549.735581  1.621883e+05  66458.723733  6.756683e+04  3.509679e+11
#
#           marketCap
# count  7.294600e+04
# mean   1.474922e+10
# std    7.501159e+10
# min    0.000000e+00
# 25%    1.860432e+08
# 50%    1.268539e+09
# 75%    5.118618e+09
# max    1.274831e+12

# %%
df['crypto_name'].unique()
# Out:
# array(['Bitcoin', 'Litecoin', 'XRP', 'Dogecoin', 'Monero', 'Stellar',
#        'Tether', 'Ethereum', 'Ethereum Classic', 'Maker',
#        'Basic Attention Token', 'EOS', 'Bitcoin Cash', 'BNB', 'TRON',
#        'Decentraland', 'Chainlink', 'Cardano', 'Filecoin',
#        'Theta Network', 'Huobi Token', 'Ravencoin', 'Tezos', 'VeChain',
#        'Quant', 'USD Coin', 'Cronos', 'Wrapped Bitcoin', 'Cosmos',
#        'Polygon', 'OKB', 'UNUS SED LEO', 'Algorand', 'Chiliz',
#        'THORChain', 'Terra Classic', 'FTX Token', 'Hedera', 'Binance USD',
#        'Dai', 'Solana', 'Avalanche', 'Shiba Inu', 'The Sandbox',
#        'Polkadot', 'Elrond', 'Uniswap', 'Aave', 'NEAR Protocol', 'Flow',
#        'Internet Computer', 'Casper', 'Toncoin', 'Chain', 'ApeCoin',
#        'Aptos'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 72946 entries, 0 to 72945
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   open         72946 non-null  float64
#  1   high         72946 non-null  float64
#  2   low          72946 non-null  float64
#  3   close        72946 non-null  float64
#  4   volume       72946 non-null  float64
#  5   marketCap    72946 non-null  float64
#  6   timestamp    72946 non-null  object
#  7   crypto_name  72946 non-null  object
#  8   date         72946 non-null  object
# dtypes: float64(6), object(3)
# memory usage: 5.6+ MB

# %%
df.isnull().sum()
# Out:
# open           0
# high           0
# low            0
# close          0
# volume         0
# marketCap      0
# timestamp      0
# crypto_name    0
# date           0
# dtype: int64

# %%
# Narx o‘zgarishini ko‘rish (volatillik):

df['volatility'] = df['high'] - df['low']

# %%
df['price_change'] = df['close'] - df['open']

# %%
df['percentage_change'] = (df['close'] - df['open']) / df['open'] * 100

# %%
df.head()
# Out:
#          open        high         low       close  volume     marketCap  \
# 0  112.900002  118.800003  107.142998  115.910004     0.0  1.288693e+09
# 1    3.493130    3.692460    3.346060    3.590890     0.0  6.229819e+07
# 2  115.980003  124.663002  106.639999  112.300003     0.0  1.249023e+09
# 3    3.594220    3.781020    3.116020    3.371250     0.0  5.859436e+07
# 4  112.250000  113.444000   97.699997  111.500000     0.0  1.240594e+09
#
#                   timestamp crypto_name        date  volatility  price_change  \
# 0  2013-05-05T23:59:59.999Z     Bitcoin  2013-05-05   11.657005      3.010002
# 1  2013-05-05T23:59:59.999Z    Litecoin  2013-05-05    0.346400      0.097760
# 2  2013-05-06T23:59:59.999Z     Bitcoin  2013-05-06   18.023003     -3.680000
# 3  2013-05-06T23:59:59.999Z    Litecoin  2013-05-06    0.665000     -0.222970
# 4  2013-05-07T23:59:59.999Z     Bitcoin  2013-05-07   15.744003     -0.750000
#
#    percentage_change
# 0           2.666078
# ...

# %%
df['trend'] = df['close'].diff().apply(lambda x: 'up' if x > 0 else 'down')
print(df[['crypto_name', 'date', 'trend']].head())
# Out:
#   crypto_name        date trend
# 0     Bitcoin  2013-05-05  down
# 1    Litecoin  2013-05-05  down
# 2     Bitcoin  2013-05-06    up
# 3    Litecoin  2013-05-06  down
# 4     Bitcoin  2013-05-07    up

# %%
df['volatility_percentage'] = (df['high'] - df['low']) / df['low'] * 100
print(df[['crypto_name', 'date', 'volatility_percentage']].head())
# Out:
#   crypto_name        date  volatility_percentage
# 0     Bitcoin  2013-05-05              10.879857
# 1    Litecoin  2013-05-05              10.352475
# 2     Bitcoin  2013-05-06              16.900790
# 3    Litecoin  2013-05-06              21.341325
# 4     Bitcoin  2013-05-07              16.114641

# %%
# MarketCap bo‘yicha eng katta kriptovalyutani topish:

largest_marketcap = df[df['marketCap'] == df['marketCap'].max()]
print(largest_marketcap[['crypto_name', 'marketCap', 'date']])
# Out:
#       crypto_name     marketCap        date
# 63365     Bitcoin  1.274831e+12  2021-11-08

# %%
#  Vaqt bo‘yicha narx grafigi:

import matplotlib.pyplot as plt

# Bitcoin narxlarini chizish
btc = df[df['crypto_name'] == 'Bitcoin']
plt.plot(btc['date'], btc['close'])
plt.title('Bitcoin Close Price Over Time')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.xticks(rotation=45)
plt.show()

# %%
df.head()
# Out:
#          open        high         low       close  volume     marketCap  \
# 0  112.900002  118.800003  107.142998  115.910004     0.0  1.288693e+09
# 1    3.493130    3.692460    3.346060    3.590890     0.0  6.229819e+07
# 2  115.980003  124.663002  106.639999  112.300003     0.0  1.249023e+09
# 3    3.594220    3.781020    3.116020    3.371250     0.0  5.859436e+07
# 4  112.250000  113.444000   97.699997  111.500000     0.0  1.240594e+09
#
#                   timestamp crypto_name        date  volatility  price_change  \
# 0  2013-05-05T23:59:59.999Z     Bitcoin  2013-05-05   11.657005      3.010002
# 1  2013-05-05T23:59:59.999Z    Litecoin  2013-05-05    0.346400      0.097760
# 2  2013-05-06T23:59:59.999Z     Bitcoin  2013-05-06   18.023003     -3.680000
# 3  2013-05-06T23:59:59.999Z    Litecoin  2013-05-06    0.665000     -0.222970
# 4  2013-05-07T23:59:59.999Z     Bitcoin  2013-05-07   15.744003     -0.750000
#
#    percentage_change trend  volatility_percentage
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 72946 entries, 0 to 72945
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   open                   72946 non-null  float64
#  1   high                   72946 non-null  float64
#  2   low                    72946 non-null  float64
#  3   close                  72946 non-null  float64
#  4   volume                 72946 non-null  float64
#  5   marketCap              72946 non-null  float64
#  6   timestamp              72946 non-null  object
#  7   crypto_name            72946 non-null  object
#  8   date                   72946 non-null  object
#  9   volatility             72946 non-null  float64
#  10  price_change           72946 non-null  float64
#  11  percentage_change      72946 non-null  float64
#  12  trend                  72946 non-null  object
#  13  volatility_percentage  72946 non-null  float64
# dtypes: float64(10), object(4)
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# LabelEncoder obyekti yaratish

label_encoder = LabelEncoder()
df['crypto_name'] = label_encoder.fit_transform(df['crypto_name'])
df['trend'] = label_encoder.fit_transform(df['trend'])

# %%
# datetime formatiga o'tkazish (timestamp yoki date ustuni uchun) 

df['date'] = pd.to_datetime(df['date'])
df['month'] = df['date'].dt.month
df['day'] = df['date'].dt.day
df['year'] = df['date'].dt.year
df['weekday'] = df['date'].dt.weekday

# %%
df.head()
# Out:
#          open        high         low       close  volume     marketCap  \
# 0  112.900002  118.800003  107.142998  115.910004     0.0  1.288693e+09
# 1    3.493130    3.692460    3.346060    3.590890     0.0  6.229819e+07
# 2  115.980003  124.663002  106.639999  112.300003     0.0  1.249023e+09
# 3    3.594220    3.781020    3.116020    3.371250     0.0  5.859436e+07
# 4  112.250000  113.444000   97.699997  111.500000     0.0  1.240594e+09
#
#                   timestamp  crypto_name       date  volatility  price_change  \
# 0  2013-05-05T23:59:59.999Z            8 2013-05-05   11.657005      3.010002
# 1  2013-05-05T23:59:59.999Z           30 2013-05-05    0.346400      0.097760
# 2  2013-05-06T23:59:59.999Z            8 2013-05-06   18.023003     -3.680000
# 3  2013-05-06T23:59:59.999Z           30 2013-05-06    0.665000     -0.222970
# 4  2013-05-07T23:59:59.999Z            8 2013-05-07   15.744003     -0.750000
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 72946 entries, 0 to 72945
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   open                   72946 non-null  float64
#  1   high                   72946 non-null  float64
#  2   low                    72946 non-null  float64
#  3   close                  72946 non-null  float64
#  4   volume                 72946 non-null  float64
#  5   marketCap              72946 non-null  float64
#  6   timestamp              72946 non-null  object
#  7   crypto_name            72946 non-null  int64
#  8   date                   72946 non-null  datetime64[ns]
#  9   volatility             72946 non-null  float64
#  10  price_change           72946 non-null  float64
#  11  percentage_change      72946 non-null  float64
#  12  trend                  72946 non-null  int64
#  13  volatility_percentage  72946 non-null  float64
# ...

# %%
df = df.drop('date', axis=1)

# %%
# Soat qismini ajratish
df['hour'] = pd.to_datetime(df['timestamp']).dt.hour
df['minute'] = pd.to_datetime(df['timestamp']).dt.minute
df['second'] = pd.to_datetime(df['timestamp']).dt.second

# %%
df = df.drop('timestamp', axis=1)

# %%
df.head(20)
# Out:
#           open        high         low       close  volume     marketCap  \
# 0   112.900002  118.800003  107.142998  115.910004     0.0  1.288693e+09
# 1     3.493130    3.692460    3.346060    3.590890     0.0  6.229819e+07
# 2   115.980003  124.663002  106.639999  112.300003     0.0  1.249023e+09
# 3     3.594220    3.781020    3.116020    3.371250     0.0  5.859436e+07
# 4   112.250000  113.444000   97.699997  111.500000     0.0  1.240594e+09
# 5     3.370870    3.406720    2.939790    3.332740     0.0  5.805127e+07
# 6     3.283620    3.491120    3.283620    3.409240     0.0  5.950822e+07
# 7   109.599998  115.779999  109.599998  113.566002     0.0  1.264049e+09
# 8     3.399400    3.441690    3.294850    3.416150     0.0  5.975557e+07
# 9   113.199997  113.459999  109.260002  112.669998     0.0  1.254535e+09
# 10  112.799004  122.000000  111.551003  117.199997     0.0  1.305479e+09
# 11    3.406530    3.631640    3.367190    3.443340     0.0  6.035893e+07
# ...

# %%
import numpy as np

df['marketCap_log'] = np.log1p(df['marketCap'])

# %%
df.head()
# Out:
#          open        high         low       close  volume     marketCap  \
# 0  112.900002  118.800003  107.142998  115.910004     0.0  1.288693e+09
# 1    3.493130    3.692460    3.346060    3.590890     0.0  6.229819e+07
# 2  115.980003  124.663002  106.639999  112.300003     0.0  1.249023e+09
# 3    3.594220    3.781020    3.116020    3.371250     0.0  5.859436e+07
# 4  112.250000  113.444000   97.699997  111.500000     0.0  1.240594e+09
#
#    crypto_name  volatility  price_change  percentage_change  trend  \
# 0            8   11.657005      3.010002           2.666078      0
# 1           30    0.346400      0.097760           2.798635      0
# 2            8   18.023003     -3.680000          -3.172961      1
# 3           30    0.665000     -0.222970          -6.203572      0
# 4            8   15.744003     -0.750000          -0.668151      1
#
#    volatility_percentage  month  day  year  weekday  hour  minute  second  \
# ...

# %%
df = df.drop('marketCap', axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 72946 entries, 0 to 72945
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   open                   72946 non-null  float64
#  1   high                   72946 non-null  float64
#  2   low                    72946 non-null  float64
#  3   close                  72946 non-null  float64
#  4   volume                 72946 non-null  float64
#  5   crypto_name            72946 non-null  int64
#  6   volatility             72946 non-null  float64
#  7   price_change           72946 non-null  float64
#  8   percentage_change      72946 non-null  float64
#  9   trend                  72946 non-null  int64
#  10  volatility_percentage  72946 non-null  float64
#  11  month                  72946 non-null  int32
#  12  day                    72946 non-null  int32
#  13  year                   72946 non-null  int32
# ...
